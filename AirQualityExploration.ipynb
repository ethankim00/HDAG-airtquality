# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
import seaborn as sns
from mobility_helpers import plot_metric

# %%
bos = pd.read_csv('Sustainability Harv/Bos/aqidaily2020.csv', parse_dates=['Date'])

# %%
df_mobility
# Out:
#        Unnamed: 0        date         county       state   fips  cases  \
# 0               0  2020-02-15       Maricopa     Arizona   4013      1
# 1               1  2020-02-15    Los Angeles  California   6037      1
# 2               2  2020-02-15         Orange  California   6059      1
# 3               3  2020-02-15      San Diego  California   6073      1
# 4               4  2020-02-15  San Francisco  California   6075      2
# ...           ...         ...            ...         ...    ...    ...
# 41127       41303  2020-06-14          Brown   Wisconsin  55009   2469
# 41128       41304  2020-06-14           Dane   Wisconsin  55025    956
# 41129       41305  2020-06-14      Milwaukee   Wisconsin  55079   9511
# 41130       41306  2020-06-14      Outagamie   Wisconsin  55087    337
# 41131       41307  2020-06-14       Waukesha   Wisconsin  55133    904
#
#        deaths                          date_county country_region  \
# ...

# %% [markdown]
# # Read in Data

# %%
df_mobility = pd.read_csv('Data/processed_mobility.csv')
# Air Quality Data
test= pd.read_csv('Sustainability Harv/aqidaily2020.csv')

# %%
test
# Out:
#            Date  Overall AQI Value Main Pollutant Site Name (of Overall AQI)  \
# 0    01/01/2020                 54            NO2                 Globeville
# 1    01/02/2020                 50            NO2                 Globeville
# 2    01/03/2020                 49            NO2                 Globeville
# 3    01/04/2020                 43            NO2              DENVER - CAMP
# 4    01/05/2020                 43            NO2                 Globeville
# ..          ...                ...            ...                        ...
# 171  06/20/2020                 48          Ozone              DENVER - CAMP
# 172  06/21/2020                 34          Ozone              DENVER - CAMP
# 173  06/22/2020                 48          Ozone                    La Casa
# 174  06/23/2020                 49          Ozone                    La Casa
# 175  06/24/2020                 43          Ozone                    La Casa
#
# ...

# %%
df_aqi_2020 = pd.read_csv('Data/daily_aqi_by_county_2020.csv', parse_dates=['Date'])
df_aqi_2019 = pd.read_csv('Data/daily_aqi_by_county_2019.csv', parse_dates=['Date'])

# %%
df_aqi_2020[df_aqi_2020['county Name'] == 'Suffolk']
# Out:
#           State Name county Name  State Code  County Code       Date  AQI  \
# 19311  Massachusetts     Suffolk          25           25 2020-01-01   24
# 19312  Massachusetts     Suffolk          25           25 2020-01-02   31
# 19313  Massachusetts     Suffolk          25           25 2020-01-03   43
# 19314  Massachusetts     Suffolk          25           25 2020-01-04   47
# 19315  Massachusetts     Suffolk          25           25 2020-01-05   27
# ...              ...         ...         ...          ...        ...  ...
# 24752       New York     Suffolk          36          103 2020-03-27   44
# 24753       New York     Suffolk          36          103 2020-03-28   42
# 24754       New York     Suffolk          36          103 2020-03-29   42
# 24755       New York     Suffolk          36          103 2020-03-30   37
# 24756       New York     Suffolk          36          103 2020-03-31   41
#
#       Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
df_aqi_2020.loc[(df_aqi_2020['county Name'] == 'Suffolk') & (df_aqi_2020['State Name'] == 'Massachusetts')]
# Out:
#           State Name county Name  State Code  County Code       Date  AQI  \
# 19311  Massachusetts     Suffolk          25           25 2020-01-01   24
# 19312  Massachusetts     Suffolk          25           25 2020-01-02   31
# 19313  Massachusetts     Suffolk          25           25 2020-01-03   43
# 19314  Massachusetts     Suffolk          25           25 2020-01-04   47
# 19315  Massachusetts     Suffolk          25           25 2020-01-05   27
# ...              ...         ...         ...          ...        ...  ...
# 19367  Massachusetts     Suffolk          25           25 2020-02-26   47
# 19368  Massachusetts     Suffolk          25           25 2020-02-27   35
# 19369  Massachusetts     Suffolk          25           25 2020-02-28   35
# 19370  Massachusetts     Suffolk          25           25 2020-02-29   37
# 19371  Massachusetts     Suffolk          25           25 2020-03-01    2
#
#       Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
df_aqi_2020[df_aqi_2020['Date'] == '2020-05-13 00:00:00']
# Out:
#            State Name county Name  State Code  County Code       Date  AQI  \
# 27029  North Carolina       Swain          37          173 2020-05-13   42
#
#       Category Defining Parameter Defining Site  Number of Sites Reporting
# 27029     Good              Ozone   37-173-0007                          1

# %%
plt.plot(df_aqi_2020[df_aqi_2020['county Name'] == 'Swain']['AQI'])

# %%
fig, ax = plt.subplots(1,1, figsize = (15,10))
sns.distplot(df_aqi_2020['AQI'])

# %%
sns.distplot()

# %%
d
