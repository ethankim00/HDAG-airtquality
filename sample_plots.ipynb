# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
import seaborn as sns
from mobility_helpers import plot_metric

# %% [markdown]
# # Generate some sample plots

# %%
mobility_data = pd.read_csv('Data/processed_mobility.csv')

# %%
plot_metric(mobility_data, 'Massachusetts', 'Suffolk', 'retail')
